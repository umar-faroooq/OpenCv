# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import Image

# %%
Image(filename='./unnamed.jpeg')

# %%
image = cv.imread("./unnamed.jpeg", 0)
plt.imshow(image)

# %%
image = cv.imread("./unnamed.jpeg")
plt.imshow(image)

# %%
image = cv.imread("./unnamed.jpeg", 0)
plt.imshow(image, cmap='gray')

# %%
print(image)
# Out:
# [[ 65  73  87 ... 216 216 216]
#  [ 63  71  85 ... 216 216 216]
#  [ 60  69  83 ... 216 216 216]
#  ...
#  [207 207 207 ... 197 197 197]
#  [207 207 207 ... 197 197 197]
#  [207 207 207 ... 197 197 197]]

# %%
l = cv.imread('./unnamed.jpeg', 1)

print("Image size is ", l.shape)

print("data type of image is", l.dtype)

print("")
# Out:
# Image size is  (640, 640, 3)
# data type of image is uint8

# %%
plt.imshow(l)

# %%
l_channels_reversed = l[:, :, ::-1]
plt.imshow(l_channels_reversed)

# %%
#split the image into BGR componenets
img_nz_bgr = cv.imread("./unnamed.jpeg", cv.IMREAD_COLOR)
b,g,r  = cv.split(img_nz_bgr)

#show channels

plt.figure(figsize=[20,5])
plt.subplot(141);plt.imshow(r,cmap = "gray");plt.title("Red Channel")
plt.subplot(142);plt.imshow(g,cmap = "gray");plt.title("Green Channel")
plt.subplot(143);plt.imshow(b,cmap = "gray");plt.title("BLue Channel")

#merge
imMerged = cv.merge((b,g,r))

plt.subplot(144);plt.imshow(imMerged[:,:,::-1]);plt.title("ALL Channel")
# Out:
# Text(0.5, 1.0, 'ALL Channel')

# %%
img_nz_bgr = cv.imread("./unnamed.jpeg", cv.IMREAD_COLOR)
img_nz_rgb = cv.cvtColor(img_nz_bgr, cv.COLOR_BGR2RGB)
plt.imshow(img_nz_rgb)

# %%
#split the image into BGR componenets
img_hsv = cv.cvtColor(img_nz_bgr, cv.COLOR_BGR2HSV)
h,s,v  = cv.split(img_hsv)

#show channels

plt.figure(figsize=[20,5])
plt.subplot(141);plt.imshow(h,cmap = "gray");plt.title("H Channel")
plt.subplot(142);plt.imshow(s,cmap = "gray");plt.title("S Channel")
plt.subplot(143);plt.imshow(v,cmap = "gray");plt.title("V Channel")

#merge
# imMerged = cv.merge((b,g,r))

plt.subplot(144);plt.imshow(img_nz_bgr);plt.title("Original")
# Out:
# Text(0.5, 1.0, 'Original')

# %%
h_new = h+10
img_nz_merged = cv.merge((h_new,s,v))
img_nz_rgb = cv.cvtColor(img_nz_merged, cv.COLOR_HSV2RGB)

#show channels

plt.figure(figsize=[20,5])
plt.subplot(141);plt.imshow(h,cmap = "gray");plt.title("H Channel")
plt.subplot(142);plt.imshow(s,cmap = "gray");plt.title("S Channel")
plt.subplot(143);plt.imshow(v,cmap = "gray");plt.title("V Channel")

plt.subplot(144);plt.imshow(img_nz_rgb);plt.title("Original")
# Out:
# Text(0.5, 1.0, 'Original')

# %%
cv.imwrite("laraib.png", img_nz_rgb)
Image(filename="./laraib.png")

# %%
img_l_bgr = cv.imread("./unnamed.jpeg", cv.IMREAD_COLOR)
print("The Shape of the image  is ", img_l_bgr.shape)


img_l_gray = cv.imread("./unnamed.jpeg", cv.IMREAD_GRAYSCALE)
print("The Shape of the image  is ", img_l_gray.shape)
# Out:
# The Shape of the image  is  (640, 640, 3)
# The Shape of the image  is  (640, 640)
