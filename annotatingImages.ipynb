# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize'] = (9.0, 9.0)
from IPython.display import Image

# %%
image = cv.imread("./unnamed.jpeg", cv.IMREAD_COLOR)
plt.imshow(image[:,:,::-1])

# %%
imageLine = image.copy()
cv.line(imageLine, (200, 100), (400, 100), (0, 255, 255), thickness=5, lineType=cv.LINE_AA)
plt.imshow(imageLine[:,:,::-1])

# %%
imageRectangle = image.copy()

cv.rectangle(imageRectangle, (200,80), (400, 300), (0,255,255), thickness=5, lineType=cv.LINE_8);

plt.imshow(imageRectangle[:,:,::-1])

# %%
imageText = image.copy()

text =  "Laraib's Picture"
fontScale = 2.3
fontFace = cv.FONT_HERSHEY_PLAIN
fontColor = (0, 255, 0)
fontThickness = 2


cv.putText(imageText, text, (200, 550), fontFace, fontScale, fontColor, fontThickness, cv.LINE_AA)

plt.imshow(imageText[:,:,::-1])

# %%
imageCircle = image.copy()
cv.circle(imageCircle, (300, 180), 100, (0,0,255), thickness=5, lineType=cv.LINE_AA);
plt.imshow(imageCircle[:,:,::-1])
