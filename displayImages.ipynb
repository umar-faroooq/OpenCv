# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
cb_img = cv.imread("./unnamed.jpeg")
coke_image = cv.imread("./laraib.png")

# %%
plt.imshow(cb_img)
plt.title("matplotlib image")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.imshow(coke_image)
plt.title("matplotlib image")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
window1 = cv.namedWindow("w1")
cv.imshow(window1, cb_img)
cv.waitKey(4000)
cv.destroyWindow(window1)


window2 = cv.namedWindow("w2")
cv.imshow(window2, coke_image)
cv.waitKey(4000)
cv.destroyWindow(window2)

window3 = cv.namedWindow("w3")
cv.imshow(window3, cb_img)
cv.waitKey(8000)
cv.destroyWindow(window3)


window4 = cv.namedWindow("w4")


Alive = True
while Alive:
    cv.imshow(window4, coke_image)
    keypress = cv.waitkey(1)
    if keypress == ORD('q'):
        Alive = False
cv.destroyWindow(window4)

cv.destroyAllWindow()
stop = 1
# Out:
# QObject::moveToThread: Current thread (0x243dcf0) is not the object's thread (0x2a9bcc0).
# Cannot move to target thread (0x243dcf0)
#
# QObject::moveToThread: Current thread (0x243dcf0) is not the object's thread (0x2a9bcc0).
# Cannot move to target thread (0x243dcf0)
#
# QObject::moveToThread: Current thread (0x243dcf0) is not the object's thread (0x2a9bcc0).
# Cannot move to target thread (0x243dcf0)
#
# QObject::moveToThread: Current thread (0x243dcf0) is not the object's thread (0x2a9bcc0).
# Cannot move to target thread (0x243dcf0)
#
# QObject::moveToThread: Current thread (0x243dcf0) is not the object's thread (0x2a9bcc0).
# Cannot move to target thread (0x243dcf0)
#
# QObject::moveToThread: Current thread (0x243dcf0) is not the object's thread (0x2a9bcc0).
# Cannot move to target thread (0x243dcf0)
#
# QObject::moveToThread: Current thread (0x243dcf0) is not the object's thread (0x2a9bcc0).
# Cannot move to target thread (0x243dcf0)
#
# ...
